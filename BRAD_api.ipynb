# %% [markdown]
# <a href="https://colab.research.google.com/github/ABHAY1937/Projects-based-on-BARDai/blob/main/BRAD_api.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install bardapi
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
pip install gTTS
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
pip install git+https://github.com/dsdanielpark/Bard-API.git
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/dsdanielpark/Bard-API.git to /tmp/pip-req-build-atqalvfn
#   Running command git clone --filter=blob:none --quiet https://github.com/dsdanielpark/Bard-API.git /tmp/pip-req-build-atqalvfn
#   Resolved https://github.com/dsdanielpark/Bard-API.git to commit e1a57f870b2621237360762ef453bca68348f779
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.4/75.4 kB 8.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 7.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 6.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.4 MB/s eta 0:00:00
# ...
#   Created wheel for bardapi: filename=bardapi-0.1.17-py3-none-any.whl size=17563 sha256=5979fe690ce9cf1ed33243354433eb3f2c803683b4814673dd2de535702ea307
# ...

# %%
from bardapi import Bard
token = "XQiY_1HZh6kgXBgSMkSFDnG25JbrmD8Ngl_vGTbg1a5mtY9fqCZxPB6RoCNh8ntsYxmRAQ."
bard = Bard(token=token)
bard.get_answer("Hi Good Morning")["content"]
# Out:
# 'Hi! Good morning to you too! How can I help you today?'

# %%
bard.get_answer("Hi Good Morning")
# Out:
# {'content': 'Hi! Good morning to you too! How can I help you today? \r\n\r\nIs there anything specific you need help with? I can help you with a variety of tasks, such as:\r\n* Writing different kinds of creative content, like poems, code, scripts, musical pieces, email, letters, etc.\r\n* Answering your questions in an informative way, even if they are open ended, challenging, or strange.\r\n* Translating languages.\r\n* Generating different creative text formats of text content.\r\n\r\nPlease let me know if you have any questions or requests.',
#  'conversation_id': 'c_827180d6737b229e',
#  'response_id': 'r_8a637d45c9b12538',
#  'factualityQueries': [],
#  'textQuery': ['Good Morning', 1],
#  'choices': [{'id': 'rc_8a637d45c9b1250b',
# ...

# %%
type(bard.get_answer("What is data science"))
# Out:
# dict

# %%
x = bard.get_answer("what is data science")["content"]

# %%
x
# Out:
# 'Data science is a field that uses scientific methods, processes, algorithms and systems to extract knowledge and insights from structured and unstructured data. It is a relatively new field, but it has grown rapidly in recent years due to the increasing availability of data and the development of new data analysis tools.\n\nData scientists use a variety of techniques to analyze data, including statistical analysis, machine learning, and natural language processing. They use this data to answer questions about the world, make predictions, and develop new products and services.\n\nData science is used in a wide variety of industries, including healthcare, finance, retail, and manufacturing. It is also used by governments and other organizations to make decisions about policy, planning, and resource allocation.\n\nThe demand for data scientists is growing rapidly, and the field is expected to continue to grow in the coming years. Data scientists are in high demand because they have the
# ...

# %%
from gtts import gTTS #import google text to speech
from IPython.display import Audio #import audio method from IPython's Display classification
x = "HI I am google Bard API........."+ x
tts = gTTS(x) #provide the string convert to speech
tts.save('1.wav') #save the string converted to speech as a .wav file
sound_file = '1.wav'
Audio(sound_file, autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
